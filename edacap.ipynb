# %% [markdown]
# <a href="https://colab.research.google.com/github/A8121/BLOG/blob/main/edacap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Questions to consider for further analysis:
# 1. What is the distribution of scores for each score type?
# 2. How do the different branches perform in terms of mean scores?
# 3. Is there any correlation between 'sum', 'count', and 'mean' columns?
# 4. Are there any outliers in the data, especially in columns like 'max', 'min', 'max-min', and 'max-mean'?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/kaggle_pivot_min_descending.csv.zip')
df
# Out:
#                                             college_name score_type seat_type  \
# 0      Veermata Jijabai Technological Institute(VJTI)...    MHT-CET      TFWS
# 1      Veermata Jijabai Technological Institute(VJTI)...    MHT-CET    LOPENS
# 2      Veermata Jijabai Technological Institute(VJTI)...    MHT-CET    GOPENS
# 3                          COEP Technological University    MHT-CET     GNT3S
# 4                          COEP Technological University    MHT-CET     LNT2S
# ...                                                  ...        ...       ...
# 28372  Dhole Patil Education Society, Dhole Patil Col...    MHT-CET    GOPENH
# 28373  Rasiklal M. Dhariwal Sinhgad Technical Institu...    MHT-CET    GOPENO
# 28374  Padmashri Dr. V.B.  Kolte College of Engineeri...  JEE(Main)      GVJO
# 28375  Amar Seva Mandal's Shree Govindrao Vanjari Col...    MHT-CET      LSCH
# 28376  Godavari Foundation's Godavari College Of Engi...    MHT-CET      GVJH
#
# ...

# %%
print(df.describe())
df
# Out:
#                 sum         count           max           min          mean  \
# count  28377.000000  28377.000000  28377.000000  28377.000000  28377.000000
# mean     233.107703      3.677098     59.974110     52.102999     55.774946
# std      451.505203      5.807874     26.164252     28.700460     26.526845
# min        0.004739      1.000000      0.004739      0.004739      0.004739
# 25%       48.141988      1.000000     41.187314     26.900779     34.329932
# 50%       84.382602      2.000000     64.060928     55.218152     58.566008
# 75%      242.888443      4.000000     81.973434     76.990020     78.391101
# max     9076.725302     92.000000    100.000000     99.843394     99.910161
#
#             max-min      max-mean
# count  28377.000000  28377.000000
# mean       7.871111      4.199164
# std       14.426868      7.838619
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.060330      0.028206
# 75%        9.184018      4.882322
# ...

# %%
sns.pairplot(df)
plt.show()

# %%
print(df.isnull().sum())
# Out:
# college_name    0
# score_type      0
# seat_type       0
# branch          0
# sum             0
# count           0
# max             0
# min             0
# mean            0
# max-min         0
# max-mean        0
# dtype: int64

# %%
unique_values = {}
for column in ['college_name', 'score_type', 'seat_type', 'branch']:
    unique_values[column] = df[column].unique()

print("Unique values in categorical columns:")
print(unique_values)
# Out:
# Unique values in categorical columns:
# {'college_name': array(['Veermata Jijabai Technological Institute(VJTI), Matunga, Mumbai',
#        'COEP Technological University',
#        "Bhartiya Vidya Bhavan's Sardar Patel Institute  of Technology , Andheri, Mumbai",
#        'Pune Institute of Computer Technology, Dhankavdi, Pune',
#        'Walchand College of Engineering, Sangli',
#        "Shri Vile Parle Kelvani Mandal's Dwarkadas J. Sanghvi College of Engineering, Vile Parle,Mumbai",
#        'Institute of Chemical Technology, Matunga, Mumbai',
#        "Bansilal Ramnath Agarawal Charitable Trust's Vishwakarma Institute of Technology, Bibwewadi, Pune",
#        'Pimpri Chinchwad Education Trust, Pimpri Chinchwad College of Engineering, Pune',
#        "MKSSS's Cummins College of Engineering for Women, Karvenagar,Pune",
#        'Xavier Institute Of Engineering C/O  Xavier Technical Institute,Mahim,Mumbai',
#        'Shri Ramdeobaba College of Engineering and Management, Nagpur',
# ...

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='score_type', data=data)
plt.title('Distribution of Score Types')

plt.subplot(1, 2, 2)
sns.countplot(x='seat_type', data=data)
plt.title('Distribution of Seat_Types')

plt.show()
